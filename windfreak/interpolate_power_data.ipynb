# %%
import numpy as np
from scipy import interpolate
import pylab as pl
import csv
from pandas import *
import matplotlib.pyplot as plt

# %%
# reading CSV file

power_scan_data2 = read_csv("2023_4_9_NLTL_powerscan_25MHzstep2.csv")
power_scan_data3 = read_csv("2023_4_9_NLTL_powerscan_25MHzstep3.csv")
power_scan_data4 = read_csv("2023_4_9_NLTL_powerscan_25MHzstep4.csv")
rf_fre2 = power_scan_data2["frequency [Hz]"].tolist()
opt_power2 = power_scan_data2["input_power [dBm]"].tolist()
opt_power3 = power_scan_data3["input_power [dBm]"].tolist()
opt_power4 = power_scan_data4["input_power [dBm]"].tolist()
plt.plot(rf_fre2,opt_power2)
plt.plot(rf_fre2,opt_power3)
plt.plot(rf_fre2,opt_power4)
plt.xlabel("rf frequency/Hz")
plt.ylabel("optimal power/dBm")
plt.title("optimal input power for different frequency")
# Out:
# Text(0.5, 1.0, 'optimal input power for different frequency')

# %%
mean_opt_power =np.add(np.add(array(opt_power2), array(opt_power3)),array(opt_power4))/3
plt.plot(rf_fre2, mean_opt_power)
plt.xlabel("rf frequency/Hz")
plt.ylabel("optimal power/dBm")
plt.title("averaged optimal input power")
# Out:
# <FloatingArray>
# [  -6.744747474747475,   -6.552828282828283,   -4.979393939393939,
#    -6.322828282828282,   -2.985555555555555,   -3.637474747474746,
#   -7.1285858585858595,   -5.287070707070708,   -7.780505050505051,
#    -6.322828282828282,   -4.059393939393939,   -4.635151515151515,
#   -3.9070707070707074,                 -4.0,   -2.655555555555556,
#   -3.0555555555555554,    -4.28939393939394,   1.5413131313131296,
#   -1.7197979797979812,   0.1978787878787873,   1.0036363636363639,
#      1.57939393939394,    14.85080808080808,   14.314646464646465,
#    15.464646464646464,    4.034747474747476,    6.680505050505053,
#    2.8070707070707073,   1.1574747474747475,  -1.8340404040404044,
#   -3.4836363636363643,   1.1970707070707063,  0.19939393939393923,
#    3.1893939393939394,    4.456666666666665,    6.298181818181817,
#    3.9585858585858595,   0.7736363636363635,  -1.7197979797979812,
#  -0.33979797979798043,    11.44040404040404]
# Length: 41, dtype: Float64
# Text(0.5, 1.0, 'averaged optimal input power')

# %%
f=interpolate.interp1d(rf_fre2,mean_opt_power,"cubic")
xnew=np.linspace(0.625e9,1.625e9,101)
ynew = f(xnew)
plt.plot(xnew,ynew, label = "quadratic")
plt.xlabel("rf frequency/Hz")
plt.ylabel("optimal power/dBm")
plt.title("interpolation")
